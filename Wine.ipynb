# %% [markdown]
# # Wine

# %% [markdown]
# ### Introduction:
#
# This exercise is a adaptation from the UCI Wine dataset.
# The only pupose is to practice deleting data with pandas.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called wine

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'

wine = pd.read_csv(url)

# %%
wine.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %% [markdown]
# ### Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
wine.drop(wine.columns[[0,3,6,8,10,12,13]], axis=1, inplace=True)

# %%
wine.head()
# Out:
#    14.23  1.71  15.6  127  3.06  2.29  1.04
# 0  13.20  1.78  11.2  100  2.76  1.28  1.05
# 1  13.16  2.36  18.6  101  3.24  2.81  1.03
# 2  14.37  1.95  16.8  113  3.49  2.18  0.86
# 3  13.24  2.59  21.0  118  2.69  1.82  1.04
# 4  14.20  1.76  15.2  112  3.39  1.97  1.05

# %% [markdown]
# ### Step 5. Assign the columns as below:
#
# The attributes are (dontated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
wine.columns=[['alcohol','malic_acid','alcalinity_of_ash','magnesium','flavanoids','proanthocyanins','hue']]

# %%
wine.head()
# Out:
#   alcohol malic_acid alcalinity_of_ash magnesium flavanoids proanthocyanins  \
# 0   13.20       1.78              11.2       100       2.76            1.28
# 1   13.16       2.36              18.6       101       3.24            2.81
# 2   14.37       1.95              16.8       113       3.49            2.18
# 3   13.24       2.59              21.0       118       2.69            1.82
# 4   14.20       1.76              15.2       112       3.39            1.97
#
#     hue
# 0  1.05
# 1  1.03
# 2  0.86
# 3  1.04
# 4  1.05

# %% [markdown]
# ### Step 6. Set the values of the first 3 rows from alcohol as NaN

# %%
wine.loc[0:2, 'alcohol'] = np.nan

wine.head()
# Out:
#   alcohol malic_acid alcalinity_of_ash magnesium flavanoids proanthocyanins  \
# 0     NaN       1.78              11.2       100       2.76            1.28
# 1     NaN       2.36              18.6       101       3.24            2.81
# 2     NaN       1.95              16.8       113       3.49            2.18
# 3   13.24       2.59              21.0       118       2.69            1.82
# 4   14.20       1.76              15.2       112       3.39            1.97
#
#     hue
# 0  1.05
# 1  1.03
# 2  0.86
# 3  1.04
# 4  1.05

# %% [markdown]
# ### Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine.loc[3:4, 'magnesium'] = np.nan

wine.head(10)
# Out:
#   alcohol malic_acid alcalinity_of_ash magnesium flavanoids proanthocyanins  \
# 0     NaN       1.78              11.2     100.0       2.76            1.28
# 1     NaN       2.36              18.6     101.0       3.24            2.81
# 2     NaN       1.95              16.8     113.0       3.49            2.18
# 3   13.24       2.59              21.0       NaN       2.69            1.82
# 4   14.20       1.76              15.2       NaN       3.39            1.97
# 5   14.39       1.87              14.6      96.0       2.52            1.98
# 6   14.06       2.15              17.6     121.0       2.51            1.25
# 7   14.83       1.64              14.0      97.0       2.98            1.98
# 8   13.86       1.35              16.0      98.0       3.15            1.85
# 9   14.10       2.16              18.0     105.0       3.32            2.38
#
#     hue
# 0  1.05
# 1  1.03
# 2  0.86
# 3  1.04
# 4  1.05
# 5  1.02
# 6  1.06
# 7  1.08
# 8  1.01
# 9  1.25

# %% [markdown]
# ### Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine['alcohol'] = wine['alcohol'].fillna(10)
wine['magnesium'] = wine['magnesium'].fillna(100)
wine.head(10)
# Out:
#   alcohol malic_acid alcalinity_of_ash magnesium flavanoids proanthocyanins  \
# 0   10.00       1.78              11.2     100.0       2.76            1.28
# 1   10.00       2.36              18.6     101.0       3.24            2.81
# 2   10.00       1.95              16.8     113.0       3.49            2.18
# 3   13.24       2.59              21.0     100.0       2.69            1.82
# 4   14.20       1.76              15.2     100.0       3.39            1.97
# 5   14.39       1.87              14.6      96.0       2.52            1.98
# 6   14.06       2.15              17.6     121.0       2.51            1.25
# 7   14.83       1.64              14.0      97.0       2.98            1.98
# 8   13.86       1.35              16.0      98.0       3.15            1.85
# 9   14.10       2.16              18.0     105.0       3.32            2.38
#
#     hue
# 0  1.05
# 1  1.03
# 2  0.86
# 3  1.04
# 4  1.05
# 5  1.02
# 6  1.06
# 7  1.08
# 8  1.01
# 9  1.25

# %% [markdown]
# ### Step 9. Count the number of missing values

# %%
wine.isnull().sum()
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# #### The technical definition of the count method is to count the non-missing values. Since all your values are non-missing it simply returns the number of rows for each group.

# %%
wine.shape #Count returns 177
# Out:
# (177, 7)

# %% [markdown]
# ### Step 10.  Create an array of 10 random numbers up until 10

# %%
arr = np.random.randint(10, size=10)

arr
# Out:
# array([4, 4, 9, 0, 2, 7, 4, 7, 2, 6])

# %% [markdown]
# ### Step 11.  Use random numbers you generated as an index and assign NaN value to each of cell.

# %%
wine.loc[arr, 'alcohol'] = np.nan
wine.head(10)
# Out:
#   alcohol malic_acid alcalinity_of_ash magnesium flavanoids proanthocyanins  \
# 0     NaN       1.78              11.2     100.0       2.76            1.28
# 1   10.00       2.36              18.6     101.0       3.24            2.81
# 2     NaN       1.95              16.8     113.0       3.49            2.18
# 3   13.24       2.59              21.0     100.0       2.69            1.82
# 4     NaN       1.76              15.2     100.0       3.39            1.97
# 5   14.39       1.87              14.6      96.0       2.52            1.98
# 6     NaN       2.15              17.6     121.0       2.51            1.25
# 7     NaN       1.64              14.0      97.0       2.98            1.98
# 8   13.86       1.35              16.0      98.0       3.15            1.85
# 9     NaN       2.16              18.0     105.0       3.32            2.38
#
#     hue
# 0  1.05
# 1  1.03
# 2  0.86
# 3  1.04
# 4  1.05
# 5  1.02
# 6  1.06
# 7  1.08
# 8  1.01
# 9  1.25

# %% [markdown]
# ### Step 12.  How many missing values do we have?

# %%
wine.isnull().sum()
# Out:
# alcohol              6
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# ### Step 13. Delete the rows that contain missing values

# %%
wine.dropna(axis=0, inplace=True)

wine.head(10)
# Out:
#    alcohol malic_acid alcalinity_of_ash magnesium flavanoids proanthocyanins  \
# 1    10.00       2.36              18.6     101.0       3.24            2.81
# 3    13.24       2.59              21.0     100.0       2.69            1.82
# 5    14.39       1.87              14.6      96.0       2.52            1.98
# 8    13.86       1.35              16.0      98.0       3.15            1.85
# 10   14.12       1.48              16.8      95.0       2.43            1.57
# 11   13.75       1.73              16.0      89.0       2.76            1.81
# 12   14.75       1.73              11.4      91.0       3.69            2.81
# 13   14.38       1.87              12.0     102.0       3.64            2.96
# 14   13.63       1.81              17.2     112.0       2.91            1.46
# 15   14.30       1.92              20.0     120.0       3.14            1.97
#
#      hue
# 1   1.03
# 3   1.04
# 5   1.02
# 8   1.01
# 10  1.17
# 11  1.15
# 12  1.25
# 13  1.20
# 14  1.28
# 15  1.07

# %% [markdown]
# ### Step 14. Print only the non-null values in alcohol

# %%
wine['alcohol'].notnull()
# Out:
#     alcohol
# 1      True
# 3      True
# 5      True
# 8      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# ..      ...
# 147    True
# 148    True
# 149    True
# 150    True
# 151    True
# 152    True
# 153    True
# 154    True
# 155    True
# 156    True
# 157    True
# 158    True
# 159    True
# 160    True
# 161    True
# 162    True
# 163    True
# 164    True
# 165    True
# 166    True
# 167    True
# 168    True
# 169    True
# 170    True
# 171    True
# 172    True
# 173    True
# 174    True
# 175    True
# 176    True
#
# [171 rows x 1 columns]

# %% [markdown]
# ### Step 15.  Reset the index, so it starts with 0 again

# %%
wine.reset_index(inplace=True)
wine.head()
# Out:
#   index alcohol malic_acid alcalinity_of_ash magnesium flavanoids  \
# 0     1   10.00       2.36              18.6     101.0       3.24
# 1     3   13.24       2.59              21.0     100.0       2.69
# 2     5   14.39       1.87              14.6      96.0       2.52
# 3     8   13.86       1.35              16.0      98.0       3.15
# 4    10   14.12       1.48              16.8      95.0       2.43
#
#   proanthocyanins   hue
# 0            2.81  1.03
# 1            1.82  1.04
# 2            1.98  1.02
# 3            1.85  1.01
# 4            1.57  1.17
